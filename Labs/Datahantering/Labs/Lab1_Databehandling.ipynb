# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

college = pd.read_csv("../Data/College.csv")

# %%
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college2 = pd.read_csv("../Data/College.csv", index_col=0)
college3 = college.rename({"Unnamed: 0": "College"}, axis = 1)
college3 = college3.set_index("College")

college = college3
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
pd.plotting.scatter_matrix(college[["Top10perc", "Apps", "Enroll"]], diagonal="kde")
plt.show()

# %%
college.boxplot(column="Outstate", by="Private", figsize=(12,8))
plt.show()

# %%
college["Elite"] = pd.cut(college["Top10perc"], [0,50,100], labels=["No", "Yes"])

print(college.value_counts("Elite"))

college.boxplot(column="Outstate", by="Elite", figsize=(12,8))
plt.show()

# %%
# Välj ut några kvantitativa variabler
variabler = ["Accept", "Top10perc", "Top25perc", "Outstate"]

# Skapa en subplot med 2x2
fig, axs = plt.subplots(2, 2, figsize=(10, 6))

axs[0, 0].hist(college['ålder'], bins=10)
axs[0, 0].set_title('Ålder')

axs[0, 1].hist(college['inkomst'], bins=10)
axs[0, 1].set_title('Inkomst')

axs[1, 0].hist(college['längd'], bins=10)
axs[1, 0].set_title('Längd')

axs[1, 1].hist(college['vikt'], bins=10)
axs[1, 1].set_title('Vikt')

plt.tight_layout()
plt.show()

# %%
plt.subplot(2, 2, 1)
plt.hist(college['Accept'], bins=25)
plt.title("Accept")

plt.subplot(2, 2, 2)
plt.hist(college['Top10perc'], bins=50)
plt.title("Top10perc")

plt.subplot(2, 2, 3)
plt.hist(college['Top25perc'], bins=75)
plt.title("Top25perc")

plt.subplot(2, 2, 4)
plt.hist(college['Outstate'], bins=100)
plt.title("Outstate")

plt.tight_layout()
plt.show()

# %% [markdown]
# I så fall kan vi använda en mer allmän approach för att beskriva vad vi letar efter och vad vi hittar.
#
# Vi letar efter korrelationer mellan tre variabler:
#
# Personal spending (utgifter för personal)
# Instructional spending (utgifter för undervisning)
# Elite status (en binär variabel som indikerar om en skola är "elite" eller inte)
# Vi vill undersöka om det finns några korrelationer mellan dessa variabler, till exempel:
#
# Om personal spending ökar, ökar också instructional spending?
# Om en skola har elite status, är personal spending eller instructional spending högre?
# Om instructional spending ökar, ökar också elite status?
# För att undersöka dessa korrelationer kan vi använda statistiska metoder som korrelationsanalys, regressionanalys eller visualiseringar som scatterplot.
#
# Om vi hade tillgång till data, kunde vi beräkna korrelationskoefficienter eller skapa visualiseringar för att se om det finns några korrelationer mellan variablerna.
#
# Men utan data kan vi bara beskriva vad vi letar efter och vad vi förväntar oss att hitta.
#
# Till exempel:
#
# "Vi letar efter korrelationer mellan personal spending, instructional spending och elite status. Vi förväntar oss att hitta en positiv korrelation mellan personal spending och instructional spending, eftersom skolor med högre personal spending kanske också har högre instructional spending. Vi förväntar oss också att hitta en positiv korrelation mellan elite status och personal spending, eftersom skolor med elite status kanske har högre personal spending för att attrahera och behålla kvalificerad personal."

# %%
college[["Private","Expend", "Personal","Elite"]].describe()
# Out:
#             Expend     Personal
# mean   9660.171171  1340.642214
# std    5221.768440   677.071454
# min    3186.000000   250.000000
# 25%    6751.000000   850.000000
# 50%    8377.000000  1200.000000
# 75%   10830.000000  1700.000000
# max   56233.000000  6800.000000
